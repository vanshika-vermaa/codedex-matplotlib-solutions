# %%
# Exercise 09: Health vs. Wealth

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 

df = pd.read_csv('gapminder.csv')
df
# Out:
#         country continent  life_expectancy  gdp_per_capita  population
# 0           USA  Americas             76.8           36449   282000000
# 1        Canada  Americas             82.3           48000    38000000
# 2         China      Asia             77.4           12000  1400000000
# 3         India      Asia             69.7            7000  1380000000
# 4       Germany    Europe             81.1           46000    83000000
# 5       Nigeria    Africa             54.3            6000   210000000
# 6        Brazil  Americas             75.9           15000   213000000
# 7     Indonesia      Asia             71.7           12000   275000000
# 8        Mexico  Americas             75.0           17000   128000000
# 9         Spain    Europe             83.2           42000    47000000
# 10  Philippines      Asia             71.0            9500   114000000
# 11     Colombia  Americas             77.1           15000    51000000

# %%
plt.figure()
plt.scatter(df['life_expectancy'], df['gdp_per_capita'])

plt.title('Life Expectancy vs. GDP per Capita')
plt.xlabel('Life expectancy (years)')
plt.ylabel('GDP per capita (USD)')

plt.show()
