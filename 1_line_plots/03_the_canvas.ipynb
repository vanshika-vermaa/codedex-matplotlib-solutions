# %%
# Exercise 03: The Canvas

import matplotlib.pyplot as plt
import numpy as np

# Increasing home prices per decade in U.S.
decades = np.array([1980, 1990, 2000, 2010, 2020])
home_prices = np.array([64600, 122900, 169000, 221800, 336900])

# Visualize the U.S. housing crisis
plt.figure()
plt.plot(decades, home_prices)
plt.show()
