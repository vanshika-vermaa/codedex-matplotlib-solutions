# %%
# Exercise 08: Gearspark's Emporium

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.DataFrame({
    "Day": ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"],
    "Consumable": [42, 38, 45, 40, 52, 60, 48],
    "Weapon": [5, 4, 6, 3, 7, 9, 6],
    "Armor": [3, 2, 4, 5, 6, 7, 5],
    "Scroll": [6, 7, 5, 8, 9, 10, 7],
    "Tool": [2, 3, 2, 4, 3, 5, 4],
    "Accessory": [0, 1, 0, 1, 2, 3, 2]
})

plt.figure()
plt.plot(df['Day'], df['Weapon'])
plt.title('Weapon Sales at Gearspark\'s Emporium')
plt.xlabel('Days of the week')
plt.ylabel('Number of Weapons sold')
plt.show()
